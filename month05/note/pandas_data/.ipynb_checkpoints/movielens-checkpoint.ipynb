# %% [markdown]
# # movielens电影评分数据分析(上)

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## 读取数据

# %%
# 从用户表读取用户信息
users = pd.read_table('users.dat', header=None, names=['UserID','Gender','Age','Occupation','Zip-code'], sep='::',engine='python')

# %%
# 打印列表长度，共有6040条记录
print(len(users))
# Out:
# 6040

# %%
# 查看前五条记录
users.head(5)
# Out:
#    UserID Gender  Age  Occupation Zip-code
# 0       1      F    1          10    48067
# 1       2      M   56          16    70072
# 2       3      M   25          15    55117
# 3       4      M   45           7    02460
# 4       5      M   25          20    55455

# %%
# 同样方法，导入电影评分表
ratings = pd.read_table('ratings.dat', header=None, names=['UserID', 'MovieID', 'Rating', 'Timestamp'], sep='::',engine='python')
# 打印列表长度
print(len(ratings))
print(ratings.head(5))
# 同样方法，导入电影数据表
movies = pd.read_table('movies.dat', header=None, names=['MovieID', 'Title', 'Genres'], sep='::',engine='python')
print(len(movies))
print(movies.head(5))
# Out:
# 1000209
#    UserID  MovieID  Rating  Timestamp
# 0       1     1193       5  978300760
# 1       1      661       3  978302109
# 2       1      914       3  978301968
# 3       1     3408       4  978300275
# 4       1     2355       5  978824291
# 3883
#    MovieID                               Title                        Genres
# 0        1                    Toy Story (1995)   Animation|Children's|Comedy
# 1        2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2        3             Grumpier Old Men (1995)                Comedy|Romance
# 3        4            Waiting to Exhale (1995)                  Comedy|Drama
# 4        5  Father of the Bride Part II (1995)                        Comedy

# %% [markdown]
# ## 合并数据表

# %%
# 导入完成之后，我们可以发现这三张表类似于数据库中的表
# 要进行数据分析，我们就要将多张表进行合并才有助于分析 先将users与ratings两张表合并再跟movied合并
data = pd.merge(pd.merge(users, ratings), movies)
data.head(10)
# Out:
#    UserID Gender  Age  Occupation Zip-code  MovieID  Rating  Timestamp  \
# 0       1      F    1          10    48067     1193       5  978300760
# 1       2      M   56          16    70072     1193       5  978298413
# 2      12      M   25          12    32793     1193       4  978220179
# 3      15      M   25           7    22903     1193       4  978199279
# 4      17      M   50           1    95350     1193       5  978158471
# 5      18      F   18           3    95825     1193       4  978156168
# 6      19      M    1          10    48073     1193       5  982730936
# 7      24      F   25           7    10023     1193       5  978136709
# 8      28      F   25           1    14607     1193       3  978125194
# 9      33      M   45           3    55421     1193       5  978557765
#
#                                     Title Genres
# 0  One Flew Over the Cuckoo's Nest (1975)  Drama
# 1  One Flew Over the Cuckoo's Nest (1975)  Drama
# 2  One Flew Over the Cuckoo's Nest (1975)  Drama
# 3  One Flew Over the Cuckoo's Nest (1975)  Drama
# 4  One Flew Over the Cuckoo's Nest (1975)  Drama
# 5  One Flew Over the Cuckoo's Nest (1975)  Drama
# 6  One Flew Over the Cuckoo's Nest (1975)  Drama
# 7  One Flew Over the Cuckoo's Nest (1975)  Drama
# 8  One Flew Over the Cuckoo's Nest (1975)  Drama
# 9  One Flew Over the Cuckoo's Nest (1975)  Drama

# %% [markdown]
# ## 对数据初步描述分析

# %%
data.describe()
# Out:
#              UserID           Age    Occupation       MovieID        Rating  \
# count  1.000209e+06  1.000209e+06  1.000209e+06  1.000209e+06  1.000209e+06
# mean   3.024512e+03  2.973831e+01  8.036138e+00  1.865540e+03  3.581564e+00
# std    1.728413e+03  1.175198e+01  6.531336e+00  1.096041e+03  1.117102e+00
# min    1.000000e+00  1.000000e+00  0.000000e+00  1.000000e+00  1.000000e+00
# 25%    1.506000e+03  2.500000e+01  2.000000e+00  1.030000e+03  3.000000e+00
# 50%    3.070000e+03  2.500000e+01  7.000000e+00  1.835000e+03  4.000000e+00
# 75%    4.476000e+03  3.500000e+01  1.400000e+01  2.770000e+03  4.000000e+00
# max    6.040000e+03  5.600000e+01  2.000000e+01  3.952000e+03  5.000000e+00
#
#           Timestamp
# count  1.000209e+06
# mean   9.722437e+08
# std    1.215256e+07
# min    9.567039e+08
# 25%    9.653026e+08
# 50%    9.730180e+08
# 75%    9.752209e+08
# max    1.046455e+09

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000209 entries, 0 to 1000208
# Data columns (total 10 columns):
# UserID        1000209 non-null int64
# Gender        1000209 non-null object
# Age           1000209 non-null int64
# Occupation    1000209 non-null int64
# Zip-code      1000209 non-null object
# MovieID       1000209 non-null int64
# Rating        1000209 non-null int64
# Timestamp     1000209 non-null int64
# Title         1000209 non-null object
# Genres        1000209 non-null object
# dtypes: int64(6), object(4)
# memory usage: 83.9+ MB

# %% [markdown]
# ## 查看数据

# %%
# 合并后的每一条记录反映了每个人的年龄，职业，性别，邮编，电影ID，评分，时间戳，电影信息，电影分类等一系列信息
# 比如我们查看用户id为12的所有信息
data[data.UserID==12]
# Out:
#         UserID Gender  Age  Occupation Zip-code  MovieID  Rating  Timestamp  \
# 2           12      M   25          12    32793     1193       4  978220179
# 8929        12      M   25          12    32793     2804       5  978220237
# 11044       12      M   25          12    32793      919       5  978220120
# 133412      12      M   25          12    32793     1198       5  978218949
# 135926      12      M   25          12    32793      593       5  978220193
# 180939      12      M   25          12    32793     1247       3  978220216
# 183406      12      M   25          12    32793     1641       3  978218568
# 352131      12      M   25          12    32793     1221       5  978218949
# 375401      12      M   25          12    32793      111       5  978220179
# 380562      12      M   25          12    32793     3265       4  978218916
# 416588      12      M   25          12    32793     1233       3  978220120
# 424194      12      M   25          12    32793     1252       3  978220237
# 482755      12      M   25          12    32793      923       5  978220237
# 489027      12      M   25          12    32793      858       5  978218949
# 572856      12      M   25          12    32793     3362       3  978220273
# 573621      12      M   25          12    32793      813       3  978218949
# 573668      12      M   25          12    32793     3897       4  978218949
# 574662      12      M   25          12    32793      934       2  978218568
# 574966      12      M   25          12    32793     3658       4  978220216
# 575035      12      M   25          12    32793     1303       4  978218916
# 575345      12      M   25          12    32793      999       4  978218568
# 575631      12      M   25          12    32793     2616       1  978218568
# 576255      12      M   25          12    32793     3785       3  978218568
#
#                                          Title  \
# 2       One Flew Over the Cuckoo's Nest (1975)
# 8929                 Christmas Story, A (1983)
# 11044                 Wizard of Oz, The (1939)
# 133412          Raiders of the Lost Ark (1981)
# 135926        Silence of the Lambs, The (1991)
# 180939                    Graduate, The (1967)
# 183406                  Full Monty, The (1997)
# 352131          Godfather: Part II, The (1974)
# 375401                      Taxi Driver (1976)
# 380562     Hard-Boiled (Lashou shentan) (1992)
# 416588             Boat, The (Das Boot) (1981)
# 424194                        Chinatown (1974)
# 482755                     Citizen Kane (1941)
# 489027                   Godfather, The (1972)
# 572856                Dog Day Afternoon (1975)
# 573621                 Larger Than Life (1996)
# 573668                    Almost Famous (2000)
# 574662              Father of the Bride (1950)
# 574966           Quatermass and the Pit (1967)
# 575035       Man Who Would Be King, The (1975)
# 575345             2 Days in the Valley (1996)
# 575631                       Dick Tracy (1990)
# 576255                      Scary Movie (2000)
#
#                                     Genres
# 2                                    Drama
# 8929                          Comedy|Drama
# 11044   Adventure|Children's|Drama|Musical
# 133412                    Action|Adventure
# 135926                      Drama|Thriller
# 180939                       Drama|Romance
# 183406                              Comedy
# 352131                  Action|Crime|Drama
# 375401                      Drama|Thriller
# 380562                        Action|Crime
# 416588                    Action|Drama|War
# 424194          Film-Noir|Mystery|Thriller
# 482755                               Drama
# 489027                  Action|Crime|Drama
# 572856                  Comedy|Crime|Drama
# 573621                              Comedy
# 573668                        Comedy|Drama
# 574662                              Comedy
# 574966                              Sci-Fi
# 575035                           Adventure
# 575345                               Crime
# 575631                        Action|Crime
# 576255                       Comedy|Horror

# %% [markdown]
# ## 查看每一部电影不同性别的平均评分并计算分歧差值，之后排序

# %%
# 查看每一部电影不同性别的平均评分 data_gender接收
data_gender=data.pivot_table(index='Title',columns='Gender',values='Rating')
data_gender.head()
# Out:
# Gender                                F         M
# Title
# $1,000,000 Duck (1971)         3.375000  2.761905
# 'Night Mother (1986)           3.388889  3.352941
# 'Til There Was You (1997)      2.675676  2.733333
# 'burbs, The (1989)             2.793478  2.962085
# ...And Justice for All (1979)  3.828571  3.689024

# %%
# 查看电影分歧最大的那部电影，在原数据中体现
data_gender['diff']=np.abs(data_gender.F-data_gender.M)
print(data_gender.shape)
data_gender.head(10)
# Out:
# (3706, 3)
# Gender                                    F         M      diff
# Title
# $1,000,000 Duck (1971)             3.375000  2.761905  0.613095
# 'Night Mother (1986)               3.388889  3.352941  0.035948
# 'Til There Was You (1997)          2.675676  2.733333  0.057658
# 'burbs, The (1989)                 2.793478  2.962085  0.168607
# ...And Justice for All (1979)      3.828571  3.689024  0.139547
# 1-900 (1994)                       2.000000  3.000000  1.000000
# 10 Things I Hate About You (1999)  3.646552  3.311966  0.334586
# 101 Dalmatians (1961)              3.791444  3.500000  0.291444
# 101 Dalmatians (1996)              3.240000  2.911215  0.328785
# 12 Angry Men (1957)                4.184397  4.328421  0.144024

# %%
# 男女电影分歧最大进行排序 data_gender_sorted接收
data_gender_sorted=data_gender.sort_values(by='diff',ascending=False)
data_gender_sorted.head()
# Out:
# Gender                                                F         M      diff
# Title
# Tigrero: A Film That Was Never Made (1994)          1.0  4.333333  3.333333
# Spiders, The (Die Spinnen, 1. Teil: Der Goldene...  4.0  1.000000  3.000000
# Neon Bible, The (1995)                              1.0  4.000000  3.000000
# James Dean Story, The (1957)                        4.0  1.000000  3.000000
# Country Life (1994)                                 5.0  2.000000  3.000000

# %% [markdown]
# ## 算出每部电影平均得分并对其进行排序

# %%
#算出每部电影平均得分并对其进行排序 data_mean_rating 接收
data_mean_rating=data.pivot_table(index='Title',values='Rating')
data_mean_rating['size'] = 
data_mean_rating.head()
# Out:
#                                  Rating
# Title
# $1,000,000 Duck (1971)         3.027027
# 'Night Mother (1986)           3.371429
# 'Til There Was You (1997)      2.692308
# 'burbs, The (1989)             2.910891
# ...And Justice for All (1979)  3.713568

# %%
# 对电影平均得分排序
data_mean_rating_sorted=data_mean_rating.sort_values(by='Rating',ascending=False)
data_mean_rating_sorted.head()
# Out:
#                           Rating
# Title
# Ulysses (Ulisse) (1954)      5.0
# Lured (1947)                 5.0
# Follow the Bitch (1998)      5.0
# Bittersweet Motel (2000)     5.0
# Song of Freedom (1936)       5.0

# %% [markdown]
# ## 查看评分次数多的电影并进行排序

# %%
# 查看评分次数多的电影并进行排序   data_rating_num接收
data_rating_num = pd.crosstab(data.Title, data.Rating)
data_rating_num['count'] = np.sum(data_rating_num, axis=1)
data_rating_num.head()
# Out:
# Rating                          1   2    3   4   5  count
# Title
# $1,000,000 Duck (1971)          3   8   15   7   4     37
# 'Night Mother (1986)            4  10   25  18  13     70
# 'Til There Was You (1997)       5  20   15  10   2     52
# 'burbs, The (1989)             36  69  107  68  23    303
# ...And Justice for All (1979)   2  12   65  82  38    199

# %%
#进行排序
data_rating_num_sorted = data_rating_num.sort_values(by='count',ascending=False)
print(data_rating_num_sorted.shape)
data_rating_num_sorted.head()
# Out:
# Rating                                               1    2    3     4     5  \
# Title
# American Beauty (1999)                              83  134  358   890  1963
# Star Wars: Episode IV - A New Hope (1977)           19   62  288   796  1826
# Star Wars: Episode V - The Empire Strikes Back ...  22   83  375  1027  1483
# Star Wars: Episode VI - Return of the Jedi (1983)   39  128  589  1099  1028
# Jurassic Park (1993)                                62  197  683  1098   632
#
# Rating                                              count
# Title
# American Beauty (1999)                               3428
# Star Wars: Episode IV - A New Hope (1977)            2991
# Star Wars: Episode V - The Empire Strikes Back ...   2990
# Star Wars: Episode VI - Return of the Jedi (1983)    2883
# Jurassic Park (1993)                                 2672

# %% [markdown]
# # movielens电影评分数据分析(下)

# %% [markdown]
# ## 过滤掉评分条目数不足250条的电影

# %%
#过滤掉评分条目数不足250条的电影
data_rating_num_sorted = data_rating_num_sorted[data_rating_num_sorted.count<50]
print(data_rating_num_sorted.shape)

# %%
#对评分数量进行排序，并取前20条数据

# %% [markdown]
# ## 评分最高的十部电影

# %%
#评分最高的十部电影

# %% [markdown]
# ## 查看不同年龄的分布情况并且采用直方图进行可视化

# %% [markdown]
# ## 在原数据中标记出用户位于的年龄分组

# %% [markdown]
# ## 电影评分表中计算不同类型电影的频数

# %%
#对数据进行规整-movies

# %%
#删除level_1列，将columns为0的列重命名为genres,并重新定义数据框为movies_genres

# %%
#将原movies数据中的genres列替换成movies_genres，得到规整化处理后的movies数据

# %%
#合并。构建电影评分数据集movie_ratings

# %%
#计算movies_ratings中不同类型电影的频数
